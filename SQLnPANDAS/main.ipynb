# %% [markdown]
# # DBs and Python

# %%
import pandas as pd

# %%
df = pd.read_csv('_select_from_employees_e_join_salaries_s_on_e_emp_no_s_emp_no_wh_202406122012.csv')

# %%
df.shape
# Out:
# (4853, 10)

# %% [markdown]
# # Connect to DB from python

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
conn = pymysql.connect(
    host='localhost',
    user='root',
    passwd='root',
    db='employees'
)

# %%
curs = conn.cursor()

# %%
query ='''
        select * 
        from employees e 
        join salaries s 
        on e.emp_no = s.emp_no 
        where e.hire_date > "1999-01-01"
        '''

# %%
curs.execute(query)
# Out:
# 4853

# %%
rows = curs.fetchall()

# %%
results = []
for row in rows:
    print(row)
    results.append(row)
print()
# Out:
# (10019, datetime.date(1953, 1, 23), 'Lillian', 'Haddadi', 'M', datetime.date(1999, 4, 30), 10019, 44276, datetime.date(1999, 4, 30), datetime.date(2000, 4, 29))
# (10019, datetime.date(1953, 1, 23), 'Lillian', 'Haddadi', 'M', datetime.date(1999, 4, 30), 10019, 46946, datetime.date(2000, 4, 29), datetime.date(2001, 4, 29))
# (10019, datetime.date(1953, 1, 23), 'Lillian', 'Haddadi', 'M', datetime.date(1999, 4, 30), 10019, 46775, datetime.date(2001, 4, 29), datetime.date(2002, 4, 29))
# (10019, datetime.date(1953, 1, 23), 'Lillian', 'Haddadi', 'M', datetime.date(1999, 4, 30), 10019, 50032, datetime.date(2002, 4, 29), datetime.date(9999, 1, 1))
# (10105, datetime.date(1962, 2, 5), 'Hironoby', 'Piveteau', 'M', datetime.date(1999, 3, 23), 10105, 59258, datetime.date(1999, 5, 17), datetime.date(2000, 5, 16))
# (10105, datetime.date(1962, 2, 5), 'Hironoby', 'Piveteau', 'M', datetime.date(1999, 3, 23), 10105, 61514, datetime.date(2000, 5, 16), datetime.date(2001, 5, 16))
# ...

# %%
conn.close()
curs.close()

# %%
len(results)
# Out:
# 4853

# %%
df_pulled = pd.DataFrame(results)

# %%
df_pulled.columns = ['emp_no', 'birth_date', 'first_name', 'last_name', 'gender', 'hire_date', 'emp_no.1', 'salary', 'from_date', 'to_date']

# %%
df_pulled
# Out:
#       emp_no  birth_date first_name last_name gender   hire_date  emp_no.1  \
# 0      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30     10019
# 1      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30     10019
# 2      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30     10019
# 3      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30     10019
# 4      10105  1962-02-05   Hironoby  Piveteau      M  1999-03-23     10105
# ...      ...         ...        ...       ...    ...         ...       ...
# 4848  499610  1962-12-28   Kiyokazu  Vernadat      F  1999-08-29    499610
# 4849  499888  1959-05-30     Hilari    Smeets      M  1999-06-27    499888
# 4850  499888  1959-05-30     Hilari    Smeets      M  1999-06-27    499888
# 4851  499888  1959-05-30     Hilari    Smeets      M  1999-06-27    499888
# 4852  499888  1959-05-30     Hilari    Smeets      M  1999-06-27    499888
#
#       salary   from_date     to_date
# ...

# %% [markdown]
# # Using pandas directly to get sql (read_sql)

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
con_string = 'mysql+pymysql://root:root@localhost/employees'
engine = create_engine(con_string)

# %%
pd.read_sql(query, engine)
# Out:
#       emp_no  birth_date first_name last_name gender   hire_date  emp_no  \
# 0      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 1      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 2      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 3      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 4      10105  1962-02-05   Hironoby  Piveteau      M  1999-03-23   10105
# ...      ...         ...        ...       ...    ...         ...     ...
# 4848  499610  1962-12-28   Kiyokazu  Vernadat      F  1999-08-29  499610
# 4849  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4850  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4851  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4852  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
#
#       salary   from_date     to_date
# 0      44276  1999-04-30  2000-04-29
# ...

# %%
df_read_sql = pd.read_sql(query, engine)

# %%
df_read_sql
# Out:
#       emp_no  birth_date first_name last_name gender   hire_date  emp_no  \
# 0      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 1      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 2      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 3      10019  1953-01-23    Lillian   Haddadi      M  1999-04-30   10019
# 4      10105  1962-02-05   Hironoby  Piveteau      M  1999-03-23   10105
# ...      ...         ...        ...       ...    ...         ...     ...
# 4848  499610  1962-12-28   Kiyokazu  Vernadat      F  1999-08-29  499610
# 4849  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4850  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4851  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
# 4852  499888  1959-05-30     Hilari    Smeets      M  1999-06-27  499888
#
#       salary   from_date     to_date
# 0      44276  1999-04-30  2000-04-29
# ...

# %% [markdown]
# # Writing to DB

# %%
max_salary = df.groupby(['emp_no', 'first_name', 'last_name'])['salary'] \
    .max().reset_index()

# %%
max_salary.to_sql('max_salary', engine, if_exists='replace', index=False)
# Out:
# 1521

# %%
max_salary2 = pd.read_sql('SELECT * FROM max_salary', engine)

# %%
max_salary2
# Out:
#       emp_no first_name  last_name  salary
# 0      10019    Lillian    Haddadi   50032
# 1      10105   Hironoby   Piveteau   61514
# 2      10298   Dietrich    DuCasse   43923
# 3      10684      Aimee   Tokunaga   47683
# 4      11315      Neven    Meriste   85452
# ...      ...        ...        ...     ...
# 1516  498990       Adil    Litecky   54960
# 1517  499361  Sandeepan    Solares   64196
# 1518  499553   Hideyuki  Delgrande   72320
# 1519  499610   Kiyokazu   Vernadat   88013
# 1520  499888     Hilari     Smeets   45235
#
# [1521 rows x 4 columns]

# %%
max_salary
# Out:
#       emp_no first_name  last_name  salary
# 0      10019    Lillian    Haddadi   50032
# 1      10105   Hironoby   Piveteau   61514
# 2      10298   Dietrich    DuCasse   43923
# 3      10684      Aimee   Tokunaga   47683
# 4      11315      Neven    Meriste   85452
# ...      ...        ...        ...     ...
# 1516  498990       Adil    Litecky   54960
# 1517  499361  Sandeepan    Solares   64196
# 1518  499553   Hideyuki  Delgrande   72320
# 1519  499610   Kiyokazu   Vernadat   88013
# 1520  499888     Hilari     Smeets   45235
#
# [1521 rows x 4 columns]

# %%
max_salary.shape, max_salary2.shape
# Out:
# ((1521, 4), (1521, 4))

# %% [markdown]
# # to_sql appending a tabele

# %%
max_salary_plus = max_salary.copy()
max_salary_plus['salary'] = max_salary_plus['salary'] + 1_000_000

# %%
max_salary_plus.to_sql('max_salary', engine, if_exists='append', index=False)
# Out:
# 1521

# %%
max_salary_plus
# Out:
#       emp_no first_name  last_name   salary
# 0      10019    Lillian    Haddadi  1050032
# 1      10105   Hironoby   Piveteau  1061514
# 2      10298   Dietrich    DuCasse  1043923
# 3      10684      Aimee   Tokunaga  1047683
# 4      11315      Neven    Meriste  1085452
# ...      ...        ...        ...      ...
# 1516  498990       Adil    Litecky  1054960
# 1517  499361  Sandeepan    Solares  1064196
# 1518  499553   Hideyuki  Delgrande  1072320
# 1519  499610   Kiyokazu   Vernadat  1088013
# 1520  499888     Hilari     Smeets  1045235
#
# [1521 rows x 4 columns]

# %%
max_salary3 = pd.read_sql('SELECT * FROM max_salary', engine)

# %%
max_salary3
# Out:
#       emp_no first_name  last_name   salary
# 0      10019    Lillian    Haddadi    50032
# 1      10105   Hironoby   Piveteau    61514
# 2      10298   Dietrich    DuCasse    43923
# 3      10684      Aimee   Tokunaga    47683
# 4      11315      Neven    Meriste    85452
# ...      ...        ...        ...      ...
# 3037  498990       Adil    Litecky  1054960
# 3038  499361  Sandeepan    Solares  1064196
# 3039  499553   Hideyuki  Delgrande  1072320
# 3040  499610   Kiyokazu   Vernadat  1088013
# 3041  499888     Hilari     Smeets  1045235
#
# [3042 rows x 4 columns]

# %%
import datetime as dt

# %%
max_salary.to_sql('max_salary', engine, if_exists='replace', index=False)
# Out:
# 1521

# %%
max_salary['date_created'] = dt.datetime.now()

# %%
max_salary.to_sql('max_salary', engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Musta\miniconda3\envs\minimal_ds\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\Musta\miniconda3\envs\minimal_ds\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
# ...

# %%
max_salary3
# Out:
#       emp_no first_name  last_name   salary
# 0      10019    Lillian    Haddadi    50032
# 1      10105   Hironoby   Piveteau    61514
# 2      10298   Dietrich    DuCasse    43923
# 3      10684      Aimee   Tokunaga    47683
# 4      11315      Neven    Meriste    85452
# ...      ...        ...        ...      ...
# 3037  498990       Adil    Litecky  1054960
# 3038  499361  Sandeepan    Solares  1064196
# 3039  499553   Hideyuki  Delgrande  1072320
# 3040  499610   Kiyokazu   Vernadat  1088013
# 3041  499888     Hilari     Smeets  1045235
#
# [3042 rows x 4 columns]
